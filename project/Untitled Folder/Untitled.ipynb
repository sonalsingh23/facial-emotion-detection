# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.11it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 4.894094569711516e-11,
#    'disgust': 1.4423336538799647e-25,
#    'fear': 0.002602302993182093,
#    'happy': 99.99545812606812,
#    'sad': 1.2819038365530222e-10,
#    'surprise': 0.00011482500212878222,
#    'neutral': 0.0018237515178043395},
#   'dominant_emotion': 'happy',
#   'region': {'x': 288, 'y': 108, 'w': 226, 'h': 226},
#   'age': 30,
#   'gender': {'Woman': 77.35645174980164, 'Man': 22.643542289733887},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 7.517046481370926,
#    'indian': 2.9977094382047653,
#    'black': 0.41729575023055077,
#    'white': 50.06181597709656,
#    'middle eastern': 17.54164695739746,
#    'latino hispanic': 21.46449089050293},
#   'dominant_race': 'white'}]

# %%
type(predictions[0]['dominant_emotion'])
# Out:
# str
